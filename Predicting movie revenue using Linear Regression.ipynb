# %%
import pandas 
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np


from sklearn.linear_model import LinearRegression
# Out:
# C:\Users\hp\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\hp\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = pandas.read_csv("cost_revenue_clean.csv")

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data, columns= ["production_budget_usd"])
y = DataFrame(data, columns= ["worldwide_gross_usd"])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y, alpha=0.3)
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.title("Film budget vs Global Revenue")
plt.xlabel("Production Budget")
plt.ylabel("Worldwide Revenue")
plt.show()

# %%
regression = LinearRegression()
regression.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
#     slope coefficient

# %%
regression.coef_ #thetha_1
# Out:
# array([[3.11150918]])

# %%
regression.intercept_ #thetha_0
# Out:
# array([-7236192.72913969])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y, alpha=0.3)
plt.plot(X,regression.predict(X), color="red", linewidth=5)

plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.title("Film budget vs Global Revenue")
plt.xlabel("Production Budget")
plt.ylabel("Worldwide Revenue")
plt.show()

# %%
regression.score(X,y)
# Out:
# 0.5496485356985727

# %%
regression.predict(X)
# Out:
# array([[-4.12468355e+06],
#        [-7.20507764e+06],
#        [-5.99158906e+06],
#        ...,
#        [ 9.44885617e+08],
#        [ 6.15065644e+08],
#        [ 1.31515521e+09]])

# %%
predictionOf = np.array([50000000]).reshape(1,-1)
regression.predict(predictionOf)
# Out:
# array([[1.48339266e+08]])

# %% [markdown]
# # A movie of 50 Million budget will give us a revenue of 148.3 million
